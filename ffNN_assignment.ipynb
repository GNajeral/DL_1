# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Victor Morcuende Castell
# - Alumno 2: Guillermo Najera Lavid
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem (28th Feb - 7th Mar).
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task (7th Mar - 14th Mar).
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning (14th Mar - 23rd Mar)
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/UeDNT7JEYFkCVPP](https://drive.upm.es/s/UeDNT7JEYFkCVPP)

# %%
import tensorflow as tf

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'CARGO_PLANE', 1: 'HELICOPTER', 2: 'SMALL_CAR', 3: 'BUS', 4: 'TRUCK', 5: 'MOTORBOAT', 6: 'FISHING_VESSEL', 7: 'DUMP_TRUCK', 8: 'EXCAVATOR', 9: 'BUILDING', 10: 'STORAGE_TANK', 11: 'SHIPPING_CONTAINER'}

# %%
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open(filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show(fig)

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json

# Load database
#json_file = "C:/Users/guill/Downloads/xview_recognition/xview_recognition/xview_ann_train.json"
json_file = "/Users/victor/Downloads/xview_recognition/xview_ann_train.json"
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'], json_data['annotations']):
    image = GenericImage("/Users/victor/Downloads/xview_recognition/" + json_img['file_name'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.id = json_ann['id']
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = list(categories.values())[json_ann['category_id']-1]
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'CARGO_PLANE': 635, 'HELICOPTER': 70, 'SMALL_CAR': 11675, 'BUS': 4017, 'TRUCK': 5836, 'MOTORBOAT': 571, 'FISHING_VESSEL': 457, 'DUMP_TRUCK': 1108, 'EXCAVATOR': 741, 'BUILDING': 13011, 'STORAGE_TANK': 1249, 'SHIPPING_CONTAINER': 816}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D, LeakyReLU
from tensorflow.keras.regularizers import l1, l2
from keras.initializers import he_normal

print('Load model')
model = Sequential()

model.add(Conv2D(32, (3,3), input_shape=(224, 224, 3), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))

model.add(Conv2D(64, (3,3), input_shape=(224, 224, 3), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))

model.add(Conv2D(128, (3,3), input_shape=(224, 224, 3), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))

model.add(Conv2D(256, (3,3), input_shape=(224, 224, 3), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))

model.add(Conv2D(512, (3,3), input_shape=(224, 224, 3), kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))
model.add(Dropout(0.3))

model.add(Conv2D(1024, (3,3), input_shape=(224, 224, 3), kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001), kernel_initializer="he_normal"))
model.add(MaxPooling2D(2,2))
model.add(BatchNormalization())
model.add(Activation('gelu'))
model.add(Dropout(0.3))
model.add(Flatten(input_shape=(224, 224, 3)))

model.add(Dense(512, kernel_regularizer=l1(0.001), bias_regularizer=l1(0.001), kernel_initializer="he_normal"))
model.add(BatchNormalization())
model.add(Activation('gelu'))
model.add(Dropout(0.4))

model.add(Dense(256, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001), kernel_initializer="he_normal"))
model.add(BatchNormalization())
model.add(Activation('gelu'))
model.add(Dropout(0.4))

model.add(Dense(128, kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001), kernel_initializer="he_normal"))
model.add(BatchNormalization())
model.add(Activation('gelu'))
model.add(Dropout(0.4))

model.add(Dense(len(categories), kernel_regularizer=l2(0.001), bias_regularizer=l2(0.001)))
model.add(Activation('softmax'))
model.summary()
# Out:
# Load model
# Metal device set to: Apple M2 Max
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# 2023-03-12 21:19:21.858437: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-12 21:19:21.858564: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 111, 111, 32)     128
#  ormalization)
#
#  activation (Activation)     (None, 111, 111, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 54, 54, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 26, 26, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 12, 12, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 512)       1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 512)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 5, 5, 512)        2048
#  hNormalization)
#
#  activation_4 (Activation)   (None, 5, 5, 512)         0
#
#  dropout (Dropout)           (None, 5, 5, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 1024)        4719616
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 1024)       0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 1, 1, 1024)       4096
#  hNormalization)
#
#  activation_5 (Activation)   (None, 1, 1, 1024)        0
#
#  dropout_1 (Dropout)         (None, 1, 1, 1024)        0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_7 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_8 (Activation)   (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 12)                1548
#
#  activation_9 (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 6,990,412
# Trainable params: 6,984,588
# Non-trainable params: 5,824
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Learning rate is changed to 0.001
#opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.00, amsgrad=True, clipnorm=1.0, clipvalue=0.5)
opt = Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=1e-8, decay=0.00, clipnorm=1.0, clipvalue=0.5)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from datetime import datetime

# Callbacks
model_checkpoint = ModelCheckpoint('model.hdf5', monitor='val_categorical_accuracy', verbose=1, save_best_only=True)
reduce_lr = ReduceLROnPlateau('val_categorical_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_categorical_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
#path = f'/Users/victor/Documents/GitHub/DL_1/logs/models/CNN_date_{datetime.now().strftime("%d-%m-%Y-%H-%M-%S")}_batch{batch_size}_epoch_{epochs}'
#tensorboard = TensorBoard(log_dir = path, histogram_freq=1)
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 256
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np
print('Training model')
epochs = 100
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h = model.fit(train_generator, steps_per_epoch=train_steps, validation_data =valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmax(h.history['val_categorical_accuracy']))
best_value = np.max(h.history['val_categorical_accuracy'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_categorical_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/100
# 2023-03-12 21:19:22.791563: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-12 21:19:23.966008: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 142/142 [==============================] - ETA: 0s - loss: 10.6953 - categorical_accuracy: 0.5662
# 2023-03-12 21:20:38.750563: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_categorical_accuracy improved from -inf to 0.41503, saving model to model.hdf5
# 142/142 [==============================] - 83s 567ms/step - loss: 10.6953 - categorical_accuracy: 0.5662 - val_loss: 4.3873 - val_categorical_accuracy: 0.4150 - lr: 0.0010
# Epoch 2/100
# 142/142 [==============================] - ETA: 0s - loss: 2.8459 - categorical_accuracy: 0.6792
# Epoch 2: val_categorical_accuracy improved from 0.41503 to 0.49266, saving model to model.hdf5
# 142/142 [==============================] - 79s 553ms/step - loss: 2.8459 - categorical_accuracy: 0.6792 - val_loss: 2.9302 - val_categorical_accuracy: 0.4927 - lr: 0.0010
# Epoch 3/100
# 142/142 [==============================] - ETA: 0s - loss: 2.2173 - categorical_accuracy: 0.7133
# Epoch 3: val_categorical_accuracy improved from 0.49266 to 0.63449, saving model to model.hdf5
# 142/142 [==============================] - 76s 539ms/step - loss: 2.2173 - categorical_accuracy: 0.7133 - val_loss: 2.3278 - val_categorical_accuracy: 0.6345 - lr: 0.0010
# Epoch 30/100
# 142/142 [==============================] - ETA: 0s - loss: 1.2129 - categorical_accuracy: 0.9141
# Epoch 30: val_categorical_accuracy did not improve from 0.78950
# 142/142 [==============================] - 83s 588ms/step - loss: 1.2129 - categorical_accuracy: 0.9141 - val_loss: 1.7311 - val_categorical_accuracy: 0.7693 - lr: 0.0010
# Epoch 31/100
# 142/142 [==============================] - ETA: 0s - loss: 1.1826 - categorical_accuracy: 0.9158
# Epoch 31: val_categorical_accuracy did not improve from 0.78950
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 142/142 [==============================] - 85s 598ms/step - loss: 1.1826 - categorical_accuracy: 0.9158 - val_loss: 1.7744 - val_categorical_accuracy: 0.7718 - lr: 0.0010
# Epoch 32/100
# 142/142 [==============================] - ETA: 0s - loss: 0.8619 - categorical_accuracy: 0.9559
# Epoch 32: val_categorical_accuracy improved from 0.78950 to 0.80244, saving model to model.hdf5
# 142/142 [==============================] - 84s 595ms/step - loss: 0.8619 - categorical_accuracy: 0.9559 - val_loss: 1.3088 - val_categorical_accuracy: 0.8024 - lr: 1.0000e-04
# Epoch 33/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6923 - categorical_accuracy: 0.9738
# Epoch 33: val_categorical_accuracy improved from 0.80244 to 0.80443, saving model to model.hdf5
# 142/142 [==============================] - 82s 580ms/step - loss: 0.6923 - categorical_accuracy: 0.9738 - val_loss: 1.2587 - val_categorical_accuracy: 0.8044 - lr: 1.0000e-04
# Epoch 34/100
# 142/142 [==============================] - ETA: 0s - loss: 0.6206 - categorical_accuracy: 0.9790
# Epoch 34: val_categorical_accuracy improved from 0.80443 to 0.80841, saving model to model.hdf5
# 142/142 [==============================] - 84s 586ms/step - loss: 0.6206 - categorical_accuracy: 0.9790 - val_loss: 1.2189 - val_categorical_accuracy: 0.8084 - lr: 1.0000e-04
# Epoch 35/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5630 - categorical_accuracy: 0.9840
# Epoch 35: val_categorical_accuracy improved from 0.80841 to 0.81314, saving model to model.hdf5
# 142/142 [==============================] - 82s 580ms/step - loss: 0.5630 - categorical_accuracy: 0.9840 - val_loss: 1.1821 - val_categorical_accuracy: 0.8131 - lr: 1.0000e-04
# Epoch 36/100
# 142/142 [==============================] - ETA: 0s - loss: 0.5176 - categorical_accuracy: 0.9870
# Epoch 36: val_categorical_accuracy did not improve from 0.81314
# 142/142 [==============================] - 79s 559ms/step - loss: 0.5176 - categorical_accuracy: 0.9870 - val_loss: 1.1782 - val_categorical_accuracy: 0.8099 - lr: 1.0000e-04
# Epoch 37/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4833 - categorical_accuracy: 0.9881
# Epoch 37: val_categorical_accuracy improved from 0.81314 to 0.81488, saving model to model.hdf5
# 142/142 [==============================] - 82s 581ms/step - loss: 0.4833 - categorical_accuracy: 0.9881 - val_loss: 1.1773 - val_categorical_accuracy: 0.8149 - lr: 1.0000e-04
# Epoch 38/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4517 - categorical_accuracy: 0.9901
# Epoch 38: val_categorical_accuracy did not improve from 0.81488
# 142/142 [==============================] - 82s 580ms/step - loss: 0.4517 - categorical_accuracy: 0.9901 - val_loss: 1.2028 - val_categorical_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 39/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4253 - categorical_accuracy: 0.9915
# Epoch 39: val_categorical_accuracy did not improve from 0.81488
# 142/142 [==============================] - 81s 571ms/step - loss: 0.4253 - categorical_accuracy: 0.9915 - val_loss: 1.1659 - val_categorical_accuracy: 0.8084 - lr: 1.0000e-04
# Epoch 40/100
# 142/142 [==============================] - ETA: 0s - loss: 0.4052 - categorical_accuracy: 0.9915
# Epoch 40: val_categorical_accuracy did not improve from 0.81488
# 142/142 [==============================] - 84s 595ms/step - loss: 0.4052 - categorical_accuracy: 0.9915 - val_loss: 1.1318 - val_categorical_accuracy: 0.8106 - lr: 1.0000e-04
# Epoch 41/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3802 - categorical_accuracy: 0.9932
# Epoch 41: val_categorical_accuracy did not improve from 0.81488
# 142/142 [==============================] - 80s 564ms/step - loss: 0.3802 - categorical_accuracy: 0.9932 - val_loss: 1.1530 - val_categorical_accuracy: 0.8089 - lr: 1.0000e-04
# Epoch 42/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3630 - categorical_accuracy: 0.9928
# Epoch 42: val_categorical_accuracy did not improve from 0.81488
# 142/142 [==============================] - 83s 584ms/step - loss: 0.3630 - categorical_accuracy: 0.9928 - val_loss: 1.1538 - val_categorical_accuracy: 0.8054 - lr: 1.0000e-04
# Epoch 43/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3449 - categorical_accuracy: 0.9941
# Epoch 43: val_categorical_accuracy improved from 0.81488 to 0.81612, saving model to model.hdf5
# 142/142 [==============================] - 81s 573ms/step - loss: 0.3449 - categorical_accuracy: 0.9941 - val_loss: 1.1329 - val_categorical_accuracy: 0.8161 - lr: 1.0000e-04
# Epoch 44/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3342 - categorical_accuracy: 0.9936
# Epoch 44: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 80s 565ms/step - loss: 0.3342 - categorical_accuracy: 0.9936 - val_loss: 1.1223 - val_categorical_accuracy: 0.8146 - lr: 1.0000e-04
# Epoch 45/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3210 - categorical_accuracy: 0.9938
# Epoch 45: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 80s 562ms/step - loss: 0.3210 - categorical_accuracy: 0.9938 - val_loss: 1.1498 - val_categorical_accuracy: 0.8034 - lr: 1.0000e-04
# Epoch 46/100
# 142/142 [==============================] - ETA: 0s - loss: 0.3079 - categorical_accuracy: 0.9941
# Epoch 46: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 81s 568ms/step - loss: 0.3079 - categorical_accuracy: 0.9941 - val_loss: 1.1353 - val_categorical_accuracy: 0.8109 - lr: 1.0000e-04
# Epoch 47/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2978 - categorical_accuracy: 0.9943
# Epoch 47: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 78s 553ms/step - loss: 0.2978 - categorical_accuracy: 0.9943 - val_loss: 1.1459 - val_categorical_accuracy: 0.8109 - lr: 1.0000e-04
# Epoch 48/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2874 - categorical_accuracy: 0.9943
# Epoch 48: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 79s 561ms/step - loss: 0.2874 - categorical_accuracy: 0.9943 - val_loss: 1.1251 - val_categorical_accuracy: 0.8154 - lr: 1.0000e-04
# Epoch 49/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2818 - categorical_accuracy: 0.9939
# Epoch 49: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 81s 574ms/step - loss: 0.2818 - categorical_accuracy: 0.9939 - val_loss: 1.1492 - val_categorical_accuracy: 0.8126 - lr: 1.0000e-04
# Epoch 50/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2680 - categorical_accuracy: 0.9949
# Epoch 50: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 80s 562ms/step - loss: 0.2680 - categorical_accuracy: 0.9949 - val_loss: 1.1455 - val_categorical_accuracy: 0.8156 - lr: 1.0000e-04
# Epoch 51/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2613 - categorical_accuracy: 0.9944
# Epoch 51: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 84s 590ms/step - loss: 0.2613 - categorical_accuracy: 0.9944 - val_loss: 1.1502 - val_categorical_accuracy: 0.8136 - lr: 1.0000e-04
# Epoch 52/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2562 - categorical_accuracy: 0.9948
# Epoch 52: val_categorical_accuracy did not improve from 0.81612
# 142/142 [==============================] - 83s 583ms/step - loss: 0.2562 - categorical_accuracy: 0.9948 - val_loss: 1.1422 - val_categorical_accuracy: 0.8116 - lr: 1.0000e-04
# Epoch 53/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2498 - categorical_accuracy: 0.9947
# Epoch 53: val_categorical_accuracy did not improve from 0.81612
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 142/142 [==============================] - 83s 584ms/step - loss: 0.2498 - categorical_accuracy: 0.9947 - val_loss: 1.1573 - val_categorical_accuracy: 0.8087 - lr: 1.0000e-04
# Epoch 54/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2254 - categorical_accuracy: 0.9960
# Epoch 54: val_categorical_accuracy improved from 0.81612 to 0.81911, saving model to model.hdf5
# 142/142 [==============================] - 87s 610ms/step - loss: 0.2254 - categorical_accuracy: 0.9960 - val_loss: 1.1148 - val_categorical_accuracy: 0.8191 - lr: 1.0000e-05
# Epoch 55/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2129 - categorical_accuracy: 0.9975
# Epoch 55: val_categorical_accuracy did not improve from 0.81911
# 142/142 [==============================] - 85s 599ms/step - loss: 0.2129 - categorical_accuracy: 0.9975 - val_loss: 1.1055 - val_categorical_accuracy: 0.8191 - lr: 1.0000e-05
# Epoch 56/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2089 - categorical_accuracy: 0.9975
# Epoch 56: val_categorical_accuracy improved from 0.81911 to 0.82010, saving model to model.hdf5
# 142/142 [==============================] - 85s 601ms/step - loss: 0.2089 - categorical_accuracy: 0.9975 - val_loss: 1.1005 - val_categorical_accuracy: 0.8201 - lr: 1.0000e-05
# Epoch 57/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2058 - categorical_accuracy: 0.9975
# Epoch 57: val_categorical_accuracy improved from 0.82010 to 0.82160, saving model to model.hdf5
# 142/142 [==============================] - 86s 608ms/step - loss: 0.2058 - categorical_accuracy: 0.9975 - val_loss: 1.0996 - val_categorical_accuracy: 0.8216 - lr: 1.0000e-05
# Epoch 58/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2046 - categorical_accuracy: 0.9973
# Epoch 58: val_categorical_accuracy did not improve from 0.82160
# 142/142 [==============================] - 82s 578ms/step - loss: 0.2046 - categorical_accuracy: 0.9973 - val_loss: 1.1029 - val_categorical_accuracy: 0.8211 - lr: 1.0000e-05
# Epoch 59/100
# 142/142 [==============================] - ETA: 0s - loss: 0.2013 - categorical_accuracy: 0.9976
# Epoch 59: val_categorical_accuracy improved from 0.82160 to 0.82259, saving model to model.hdf5
# 142/142 [==============================] - 84s 591ms/step - loss: 0.2013 - categorical_accuracy: 0.9976 - val_loss: 1.0932 - val_categorical_accuracy: 0.8226 - lr: 1.0000e-05
# Epoch 60/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1991 - categorical_accuracy: 0.9980
# Epoch 60: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 82s 575ms/step - loss: 0.1991 - categorical_accuracy: 0.9980 - val_loss: 1.1054 - val_categorical_accuracy: 0.8189 - lr: 1.0000e-05
# Epoch 61/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1963 - categorical_accuracy: 0.9982
# Epoch 61: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 82s 575ms/step - loss: 0.1963 - categorical_accuracy: 0.9982 - val_loss: 1.0980 - val_categorical_accuracy: 0.8206 - lr: 1.0000e-05
# Epoch 62/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1944 - categorical_accuracy: 0.9982
# Epoch 62: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 81s 571ms/step - loss: 0.1944 - categorical_accuracy: 0.9982 - val_loss: 1.0994 - val_categorical_accuracy: 0.8211 - lr: 1.0000e-05
# Epoch 63/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1927 - categorical_accuracy: 0.9983
# Epoch 63: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 81s 574ms/step - loss: 0.1927 - categorical_accuracy: 0.9983 - val_loss: 1.0953 - val_categorical_accuracy: 0.8213 - lr: 1.0000e-05
# Epoch 64/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1908 - categorical_accuracy: 0.9981
# Epoch 64: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 83s 582ms/step - loss: 0.1908 - categorical_accuracy: 0.9981 - val_loss: 1.0935 - val_categorical_accuracy: 0.8223 - lr: 1.0000e-05
# Epoch 65/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1889 - categorical_accuracy: 0.9984
# Epoch 65: val_categorical_accuracy did not improve from 0.82259
# 142/142 [==============================] - 82s 575ms/step - loss: 0.1889 - categorical_accuracy: 0.9984 - val_loss: 1.0909 - val_categorical_accuracy: 0.8221 - lr: 1.0000e-05
# Epoch 66/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1868 - categorical_accuracy: 0.9982
# Epoch 66: val_categorical_accuracy improved from 0.82259 to 0.82309, saving model to model.hdf5
# 142/142 [==============================] - 84s 588ms/step - loss: 0.1868 - categorical_accuracy: 0.9982 - val_loss: 1.0939 - val_categorical_accuracy: 0.8231 - lr: 1.0000e-05
# Epoch 67/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1842 - categorical_accuracy: 0.9986
# Epoch 67: val_categorical_accuracy did not improve from 0.82309
# 142/142 [==============================] - 82s 579ms/step - loss: 0.1842 - categorical_accuracy: 0.9986 - val_loss: 1.0923 - val_categorical_accuracy: 0.8201 - lr: 1.0000e-05
# Epoch 68/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1825 - categorical_accuracy: 0.9986
# Epoch 68: val_categorical_accuracy did not improve from 0.82309
# 142/142 [==============================] - 81s 570ms/step - loss: 0.1825 - categorical_accuracy: 0.9986 - val_loss: 1.0919 - val_categorical_accuracy: 0.8194 - lr: 1.0000e-05
# Epoch 69/100
# 142/142 [==============================] - ETA: 0s - loss: 0.1810 - categorical_accuracy: 0.9985
# Epoch 69: val_categorical_accuracy did not improve from 0.82309
# 142/142 [==============================] - 84s 592ms/step - loss: 0.1810 - categorical_accuracy: 0.9985 - val_loss: 1.0935 - val_categorical_accuracy: 0.8216 - lr: 1.0000e-05
# Epoch 70/100
# 122/142 [========================>.....] - ETA: 11s - loss: 0.1797 - categorical_accuracy: 0.9984

# %% [markdown]
# #### Testing
# Try to improve the results provided in the Moodle competition wiki.

# %%
import matplotlib.pyplot as plt
import pandas as pd
metrics = h.history
plt.plot(h.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()
plt.plot(h.epoch, metrics['categorical_accuracy'], metrics['val_categorical_accuracy'])
plt.legend(['accuracy', 'val_categorical_accuracy'])
plt.show()

# %%
import json

# Load database
json_file = "/Users/victor/Downloads/xview_recognition/xview_ann_test.json"
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

anns = []
for json_img, json_ann in zip(json_data['images'], json_data['annotations']):
    image = GenericImage("/Users/victor/Downloads/xview_recognition/" + json_img['file_name'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.id = json_ann['id']
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = list(categories.values())[json_ann['category_id']-1]
    image.add_object(obj)
    anns.append(image)

# %%
import numpy as np

# model.load_weights('model.hdf5', by_name=True)
y_true, y_pred = [], []
for ann in anns:
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        y_true.append(obj_pred.category)
        y_pred.append(pred_category)

# %%
from sklearn.metrics import confusion_matrix

# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
import numpy as np

# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))

# %% [markdown]
# #### Report
#
# You must prepare a report (PDF) describing:
# * The problems and data sets (briefly).
# * The process that you have followed to reach your solution for the “xview_recognition” benchmark, including your intermediate results. You must discuss and compare these results properly.
# * Final network architectures, including optimization algorithms, regularization methods (dropout, data augmentation, etc.), number of layers/parameters, and performance obtained with your model on the train/valid/test data sets, including the plots of the evolution of losses and accuracy.
# * It would also be very valuable your feedback on the use of “Cesvima” or “Google Colab" services.
#
# In the submission via Moodle, attach your Python (.py) or Jupyter Notebook (.ipynb) source file, including in the report all results of computations attached to the code that generated them.
#
# The assignment must be done in groups of 3 students. Each team must submit one submission before Tuesday, April 18th, 2023, 23:55h.
